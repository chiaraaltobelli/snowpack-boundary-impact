# %%
import xarray as xr
import os

base_dir = "/bsushare/leaf-shared/subset-output-wrf/vol04/wrf_out/wy_2000/d01/"
filename = "T2_2000-03.nc"
path = os.path.join(base_dir, filename)

ds = xr.open_dataset(path)
print(ds)

# Look at shapes
print("T2 shape:", ds["T2"].shape)

# Print coordinate arrays
print("Latitude shape:", ds["XLAT"].shape)
print("Longitude shape:", ds["XLONG"].shape)

# Print a few example values
print("Sample latitudes:", ds["XLAT"][0, ::20, ::20].values)
print("Sample longitudes:", ds["XLONG"][0, ::20, ::20].values)
# Out:
# <xarray.Dataset> Size: 875MB
# Dimensions:  (Time: 744, south_north: 289, west_east: 339)
# Coordinates:
#     XLAT     (Time, south_north, west_east) float32 292MB ...
#     XLONG    (Time, south_north, west_east) float32 292MB ...
#     XTIME    (Time) datetime64[ns] 6kB ...
# Dimensions without coordinates: Time, south_north, west_east
# Data variables:
#     T2       (Time, south_north, west_east) float32 292MB ...
# Attributes: (12/135)
#     TITLE:                            OUTPUT FROM WRF V3.8.1 MODEL
#     START_DATE:                      2000-03-01_00:00:00
#     SIMULATION_START_DATE:           1999-09-16_00:00:00
#     WEST-EAST_GRID_DIMENSION:        340
#     SOUTH-NORTH_GRID_DIMENSION:      290
#     BOTTOM-TOP_GRID_DIMENSION:       50
#     ...                              ...
#     ISLAKE:                          21
#     ISICE:                           15
#     ISURBAN:                         13
#     ISOILWATER:                      14
# ...
